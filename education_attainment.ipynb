# %%
# !pip install ydata-profiling >> dev/null
# Out:
# /bin/bash: line 1: dev/null: No such file or directory

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('datasets/EDUCATION_ATTAINMENT.csv')
df.head()
# Out:
#    Ages[15-49]_All_grade1  Ages[15-49]_All_grade2  Ages[15-49]_All_grade3  \
# 0                0.669091                0.667214                0.651812
# 1                0.485879                0.480171                0.465510
# 2                0.516431                0.514233                0.502269
# 3                0.914294                0.903528                0.871690
# 4                0.876990                0.841497                0.762864
#
#    Ages[20-29]_All_grade1  Ages[20-29]_All_grade2  Ages[20-29]_All_grade3  \
# 0                0.460899                0.458749                0.446925
# 1                0.267236                0.265735                0.257999
# 2                0.327775                0.326250                0.318003
# 3                0.853770                0.840792                0.810794
# 4                0.881265                0.854158                0.795892
#
# ...

# %%
#Get the generation information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ages[15-49]_All_grade1     626 non-null    float64
#  1   Ages[15-49]_All_grade2     626 non-null    float64
#  2   Ages[15-49]_All_grade3     626 non-null    float64
#  3   Ages[20-29]_All_grade1     626 non-null    float64
#  4   Ages[20-29]_All_grade2     626 non-null    float64
#  5   Ages[20-29]_All_grade3     626 non-null    float64
#  6   Ages[30-39]_All_grade1     625 non-null    float64
#  7   Ages[30-39]_All_grade2     625 non-null    float64
#  8   Ages[30-39]_All_grade3     625 non-null    float64
#  9   Ages[40-49]_All_grade1     625 non-null    float64
#  10  Ages[40-49]_All_grade2     625 non-null    float64
#  11  Ages[40-49]_All_grade3     625 non-null    float64
#  12  Ages[15-49]_Male_grade1    626 non-null    float64
# ...

# %%
#Descriptive analysis of the dataset
df.describe(include='all')
# Out:
#         Ages[15-49]_All_grade1  Ages[15-49]_All_grade2  \
# count               626.000000              626.000000
# unique                     NaN                     NaN
# top                        NaN                     NaN
# freq                       NaN                     NaN
# mean                  0.873886                0.861490
# std                   0.162624                0.166895
# min                   0.251917                0.244071
# 25%                   0.831791                0.803131
# 50%                   0.948926                0.935167
# 75%                   0.984447                0.980112
# max                   1.000000                1.000000
#
#         Ages[15-49]_All_grade3  Ages[20-29]_All_grade1  \
# count               626.000000              626.000000
# unique                     NaN                     NaN
# top                        NaN                     NaN
# freq                       NaN                     NaN
# ...

# %%
#Checking the null values
df.isnull().sum()
# Out:
# Ages[15-49]_All_grade1       0
# Ages[15-49]_All_grade2       0
# Ages[15-49]_All_grade3       0
# Ages[20-29]_All_grade1       0
# Ages[20-29]_All_grade2       0
# Ages[20-29]_All_grade3       0
# Ages[30-39]_All_grade1       1
# Ages[30-39]_All_grade2       1
# Ages[30-39]_All_grade3       1
# Ages[40-49]_All_grade1       1
# Ages[40-49]_All_grade2       1
# Ages[40-49]_All_grade3       1
# Ages[15-49]_Male_grade1      0
# Ages[15-49]_Male_grade2      0
# Ages[15-49]_Male_grade3      0
# Ages[20-29]_Male_grade1      0
# Ages[20-29]_Male_grade2      0
# Ages[20-29]_Male_grade3      0
# Ages[30-39]_Male_grade1      1
# Ages[30-39]_Male_grade2      1
# Ages[30-39]_Male_grade3      1
# Ages[40-49]_Male_grade1      1
# Ages[40-49]_Male_grade2      1
# Ages[40-49]_Male_grade3      1
# Ages[15-49]_Female_grade1    0
# Ages[15-49]_Female_grade2    0
# Ages[15-49]_Female_grade3    0
# Ages[20-29]_Female_grade1    0
# Ages[20-29]_Female_grade2    0
# Ages[20-29]_Female_grade3    0
# ...

# %%
profile = ProfileReport(df, title='Education Attainment')
# profile.to_notebook_iframe()

# %%
profile.to_file(output_file='profile-report.html')
# Out:
# Export report to file: 100%|██████████████████████| 1/1 [00:00<00:00,  5.31it/s]

# %% [markdown]
# ### Profile Report Conclusions
#
# Findings from the profile report generated by ydata_profiling:
#
# * There are 38 columns(variables) and 626 rows (observations) in the dataset.
#
# * Missing values:
#   * There are 18 missing values in total which is 0.1% of the number of values in the dataset.
#   * Only 1 value is missing on the columns where missing values are detected
#
# * Duplicates:
#      * There is only 1 duplicated row with the country value being Panama in the year 1995
#
# * Correlations
#     * All columns have a positive correlation.
#     * The age groups of males between 30-39 have the least coefficient ratio of (0.095) in relation to the year meaning that the grades of males in this age group tend to minimally increase in comparison to other age groups every year.
#
# * Interesting patterns
#     * The mean grades of the sample dataset age groups seem to have positively increased from the year 2000
